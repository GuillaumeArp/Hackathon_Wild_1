# %%
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
from sklearn.model_selection import cross_val_score
import numpy as np
import math
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
import tensorflow as tf

# %%
url = "https://raw.githubusercontent.com/murpi/wilddata/master/quests/spotify.zip"
df_music = pd.read_csv(url)
df_music.head()
# Out:
#    genre        artist_name                        track_name  \
# 0  Movie     Henri Salvador       C'est beau de faire un Show
# 1  Movie  Martin & les fées  Perdu d'avance (par Gad Elmaleh)
# 2  Movie    Joseph Williams    Don't Let Me Be Lonely Tonight
# 3  Movie     Henri Salvador    Dis-moi Monsieur Gordon Cooper
# 4  Movie       Fabien Nataf                         Ouverture
#
#                  track_id  popularity  acousticness  danceability  \
# 0  0BRjO6ga9RKCKjfDqeFgWV           0         0.611         0.389
# 1  0BjC1NfoEOOusryehmNudP           1         0.246         0.590
# 2  0CoSDzoNIKCRs124s9uTVy           3         0.952         0.663
# 3  0Gc6TVm52BwZD07Ki6tIvf           0         0.703         0.240
# 4  0IuslXpMROHdEPvSl1fTQK           4         0.950         0.331
#
#    duration_ms  energy  instrumentalness key  liveness  loudness   mode  \
# 0        99373   0.910             0.000  C#    0.3460    -1.828  Major
# 1       137373   0.737             0.000  F#    0.1510    -5.559  Minor
# 2       170267   0.131             0.000   C    0.1030   -13.879  Minor
# 3       152427   0.326             0.000  C#    0.0985   -12.178  Major
# 4        82625   0.225             0.123   F    0.2020   -21.150  Major
#
#    speechiness    tempo time_signature  valence
# 0       0.0525  166.969            4/4    0.814
# 1       0.0868  174.003            4/4    0.816
# 2       0.0362   99.488            5/4    0.368
# 3       0.0395  171.758            4/4    0.227
# 4       0.0456  140.576            4/4    0.390

# %%
# There is two columns with similar name: "Children’s Music" and "Children's Music". I rename it before a merge with the following get dummies
df_music["genre"].replace('Children’s Music', "Children's Music", inplace=True)

# Get dummies on genre for Machine Learning Usage
df_music_dumies = pd.concat([df_music , df_music['genre'].str.get_dummies()], axis = 1)

# Factorization of "mode"
df_music_dumies['mode'] = df_music_dumies['mode'].factorize()[0]

# %%
# Get dummies on key for Machine Learning Usage

df_music_dumies_keys = pd.concat([df_music_dumies , df_music_dumies['key'].str.get_dummies()], axis = 1)

# %%
# Function to split the popularity in 5 classes in order to use a classification Machine Learning method (suggested by Tarik as he says it's better than Linear Regression here)

def popularity_score(popularity):
  popularity = popularity / 20
  popularity = math.ceil(popularity)
  return popularity

# Applying the function

df_music_dumies_keys["popularity_score"] = df_music["popularity"].apply(popularity_score)

# %%
df_music_with_0_pop = df_music_dumies_keys
df_music_without_0_pop = df_music_dumies_keys[df_music_dumies_keys['popularity_score'] != 0]

# %%
cols = ['acousticness', 'danceability', 'duration_ms', 'energy',
       'instrumentalness', 'liveness', 'loudness', 'mode',
       'speechiness', 'tempo', 'valence', 'A Capella',
       'Alternative', 'Anime', 'Blues', "Children's Music",
       'Classical', 'Comedy', 'Country', 'Dance', 'Electronic', 'Folk',
       'Hip-Hop', 'Indie', 'Jazz', 'Movie', 'Opera', 'Pop', 'R&B', 'Rap',
       'Reggae', 'Reggaeton', 'Rock', 'Ska', 'Soul', 'Soundtrack', 'World', 'A', 'A#', 'B', 'C', 'C#',
       'D', 'D#', 'E', 'F', 'F#', 'G', 'G#']

X = df_music_with_0_pop[cols]
y = df_music_with_0_pop['popularity_score']

# %%
# Test without the value 0 in popularity

X = df_music_without_0_pop[cols]
y = df_music_without_0_pop['popularity_score']

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 2, train_size=0.75)

# %%
N, D = X_train.shape
print(N)
print(D)
# Out:
# 169809
# 49

# %%
y_train.value_counts()
# Out:
# 3    71241
# 2    54551
# 4    23639
# 1    19627
# 5      751
# Name: popularity_score, dtype: int64

# %%
le = LabelEncoder()
target_label_encoded = le.fit_transform(y_test)

# %%
N, D = X_train.shape


scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
model = tf.keras.models.Sequential([
tf.keras.layers.Input(shape=(D,)),
tf.keras.layers.Dense(10, activation='relu'),
tf.keras.layers.Dense(6, activation = 'softmax')
])
model.compile(optimizer='adam',
loss='sparse_categorical_crossentropy',
metrics=['accuracy'])
r = model.fit(X_train, y_train, validation_data=(X_test, target_label_encoded), epochs=100)
print("Train score:", model.evaluate(X_train, y_train))
print("Test score:", model.evaluate(X_test, target_label_encoded))
# Out:
# Epoch 1/100
# 5307/5307 [==============================] - 3s 656us/step - loss: 0.8194 - accuracy: 0.6588 - val_loss: 3.8217 - val_accuracy: 0.2199
# Epoch 2/100
# 5307/5307 [==============================] - 3s 609us/step - loss: 0.7501 - accuracy: 0.6818 - val_loss: 4.2942 - val_accuracy: 0.2132
# Epoch 3/100
# 5307/5307 [==============================] - 3s 634us/step - loss: 0.7460 - accuracy: 0.6838 - val_loss: 4.7001 - val_accuracy: 0.2231
# Epoch 4/100
# 5307/5307 [==============================] - 3s 618us/step - loss: 0.7436 - accuracy: 0.6840 - val_loss: 5.1371 - val_accuracy: 0.2195
# Epoch 5/100
# 5307/5307 [==============================] - 3s 633us/step - loss: 0.7425 - accuracy: 0.6843 - val_loss: 5.5457 - val_accuracy: 0.2168
# Epoch 6/100
# 5307/5307 [==============================] - 4s 686us/step - loss: 0.7413 - accuracy: 0.6853 - val_loss: 5.7648 - val_accuracy: 0.2220
# Epoch 7/100
# 5307/5307 [==============================] - 5s 993us/step - loss: 0.7412 - accuracy: 0.6848 - val_loss: 5.9196 - val_accuracy: 0.2123
# Epoch 8/100
# 5307/5307 [==============================] - 6s 1ms/step - loss: 0.7406 - accuracy: 0.6846 - val_loss: 5.9366 - val_accuracy: 0.2223
# Epoch 9/100
# 5307/5307 [==============================] - 7s 1ms/step - loss: 0.7400 - accuracy: 0.6853 - val_loss: 6.1036 - val_accuracy: 0.2146
# Epoch 10/100
# 5307/5307 [==============================] - 8s 1ms/step - loss: 0.7400 - accuracy: 0.6849 - val_loss: 6.1938 - val_accuracy: 0.2162
# Epoch 11/100
# 5307/5307 [==============================] - 7s 1ms/step - loss: 0.7394 - accuracy: 0.6849 - val_loss: 6.1377 - val_accuracy: 0.2156
# Epoch 12/100
# 5307/5307 [==============================] - 8s 2ms/step - loss: 0.7392 - accuracy: 0.6857 - val_loss: 6.2370 - val_accuracy: 0.2176
# Epoch 13/100
# 5307/5307 [==============================] - 8s 1ms/step - loss: 0.7390 - accuracy: 0.6849 - val_loss: 6.2265 - val_accuracy: 0.2268
# Epoch 14/100
# 5307/5307 [==============================] - 8s 1ms/step - loss: 0.7387 - accuracy: 0.6857 - val_loss: 6.1982 - val_accuracy: 0.2263
# Epoch 15/100
# 5307/5307 [==============================] - 8s 1ms/step - loss: 0.7385 - accuracy: 0.6852 - val_loss: 6.2141 - val_accuracy: 0.2205
# Epoch 16/100
# 5307/5307 [==============================] - 7s 1ms/step - loss: 0.7383 - accuracy: 0.6850 - val_loss: 6.3329 - val_accuracy: 0.2169
# Epoch 17/100
# 5307/5307 [==============================] - 7s 1ms/step - loss: 0.7383 - accuracy: 0.6849 - val_loss: 6.4086 - val_accuracy: 0.2105
# Epoch 18/100
# 5307/5307 [==============================] - 8s 2ms/step - loss: 0.7381 - accuracy: 0.6849 - val_loss: 6.4041 - val_accuracy: 0.2161
# Epoch 19/100
# 5307/5307 [==============================] - 7s 1ms/step - loss: 0.7378 - accuracy: 0.6855 - val_loss: 6.5120 - val_accuracy: 0.2129
# Epoch 20/100
# 5307/5307 [==============================] - 7s 1ms/step - loss: 0.7378 - accuracy: 0.6856 - val_loss: 6.4867 - val_accuracy: 0.2177
# Epoch 21/100
# 5307/5307 [==============================] - 5s 1ms/step - loss: 0.7377 - accuracy: 0.6854 - val_loss: 6.5411 - val_accuracy: 0.2066
# Epoch 22/100
# 5307/5307 [==============================] - 4s 674us/step - loss: 0.7377 - accuracy: 0.6853 - val_loss: 6.5545 - val_accuracy: 0.2183
# Epoch 23/100
# 5307/5307 [==============================] - 4s 696us/step - loss: 0.7376 - accuracy: 0.6854 - val_loss: 6.5737 - val_accuracy: 0.2121
# Epoch 24/100
# 5307/5307 [==============================] - 4s 680us/step - loss: 0.7375 - accuracy: 0.6855 - val_loss: 6.5277 - val_accuracy: 0.2250
# Epoch 25/100
# 5307/5307 [==============================] - 4s 666us/step - loss: 0.7374 - accuracy: 0.6855 - val_loss: 6.6493 - val_accuracy: 0.2171
# Epoch 26/100
100
# 5307/5307 [==============================] - 7s 1ms/step - loss: 0.7366 - accuracy: 0.6854 - val_loss: 7.2283 - val_accuracy: 0.2094
# Epoch 50/100
# 5307/5307 [==============================] - 7s 1ms/step - loss: 0.7367 - accuracy: 0.6851 - val_loss: 7.2340 - val_accuracy: 0.2003
# Epoch 51/100
# 5307/5307 [==============================] - 6s 1ms/step - loss: 0.7367 - accuracy: 0.6852 - val_loss: 7.2398 - val_accuracy: 0.2170
# Epoch 52/100
# 5307/5307 [==============================] - 7s 1ms/step - loss: 0.7367 - accuracy: 0.6852 - val_loss: 7.1363 - val_accuracy: 0.2220
# Epoch 53/100
# 5307/5307 [==============================] - 7s 1ms/step - loss: 0.7366 - accuracy: 0.6853 - val_loss: 7.2220 - val_accuracy: 0.2184
# Epoch 54/100
# 5307/5307 [==============================] - 8s 1ms/step - loss: 0.7366 - accuracy: 0.6860 - val_loss: 7.2855 - val_accuracy: 0.2175
# Epoch 55/100
# 5307/5307 [==============================] - 7s 1ms/step - loss: 0.7365 - accuracy: 0.6856 - val_loss: 7.3074 - val_accuracy: 0.2154
# Epoch 56/100
# 5307/5307 [==============================] - 6s 1ms/step - loss: 0.7366 - accuracy: 0.6853 - val_loss: 7.3167 - val_accuracy: 0.2177
# Epoch 57/100
# 5307/5307 [==============================] - 6s 1ms/step - loss: 0.7366 - accuracy: 0.6854 - val_loss: 7.4140 - val_accuracy: 0.2063
# Epoch 58/100
# 5307/5307 [==============================] - 7s 1ms/step - loss: 0.7367 - accuracy: 0.6853 - val_loss: 7.3076 - val_accuracy: 0.2198
# Epoch 59/100
# 5307/5307 [==============================] - 8s 1ms/step - loss: 0.7365 - accuracy: 0.6855 - val_loss: 7.3322 - val_accuracy: 0.2173
# Epoch 60/100
# 5307/5307 [==============================] - 5s 945us/step - loss: 0.7365 - accuracy: 0.6849 - val_loss: 7.3920 - val_accuracy: 0.2152
# Epoch 61/100
# 5307/5307 [==============================] - 7s 1ms/step - loss: 0.7365 - accuracy: 0.6858 - val_loss: 7.3882 - val_accuracy: 0.2225
# Epoch 62/100
# 5307/5307 [==============================] - 7s 1ms/step - loss: 0.7366 - accuracy: 0.6850 - val_loss: 7.4151 - val_accuracy: 0.2254
# Epoch 63/100
# 5307/5307 [==============================] - 6s 1ms/step - loss: 0.7364 - accuracy: 0.6857 - val_loss: 7.3789 - val_accuracy: 0.2155
# Epoch 64/100
# 5307/5307 [==============================] - 7s 1ms/step - loss: 0.7365 - accuracy: 0.6850 - val_loss: 7.4542 - val_accuracy: 0.2136
# Epoch 65/100
# 5307/5307 [==============================] - 6s 1ms/step - loss: 0.7364 - accuracy: 0.6851 - val_loss: 7.3985 - val_accuracy: 0.2220
# Epoch 66/100
# 5307/5307 [==============================] - 6s 1ms/step - loss: 0.7365 - accuracy: 0.6855 - val_loss: 7.4321 - val_accuracy: 0.2170
# Epoch 67/100
# 5307/5307 [==============================] - 8s 1ms/step - loss: 0.7364 - accuracy: 0.6853 - val_loss: 7.4608 - val_accuracy: 0.2222
# Epoch 68/100
# 5307/5307 [==============================] - 7s 1ms/step - loss: 0.7364 - accuracy: 0.6854 - val_loss: 7.5320 - val_accuracy: 0.2115
# Epoch 69/100
# 5307/5307 [==============================] - 7s 1ms/step - loss: 0.7364 - accuracy: 0.6856 - val_loss: 7.5067 - val_accuracy: 0.2117
# Epoch 70/100
# 5307/5307 [==============================] - 7s 1ms/step - loss: 0.7363 - accuracy: 0.6851 - val_loss: 7.5916 - val_accuracy: 0.2230
# Epoch 71/100
# 5307/5307 [==============================] - 7s 1ms/step - loss: 0.7364 - accuracy: 0.6854 - val_loss: 7.5277 - val_accuracy: 0.2118
# Epoch 72/100
# 5307/5307 [==============================] - 8s 1ms/step - loss: 0.7364 - accuracy: 0.6854 - val_loss: 7.4524 - val_accuracy: 0.2183
# Epoch 73/100
# 5307/5307 [==============================] - 7s 1ms/step - loss: 0.7363 - accuracy: 0.6859 - val_loss: 7.5341 - val_accuracy: 0.2129
# Epoch 74/100
# 5307/5307 [==============================] - 7s 1ms/step - loss: 0.7362 - accuracy: 0.6853 - val_loss: 7.6245 - val_accuracy: 0.2144
# Epoch 75/100
# 5307/5307 [==============================] - 7s 1ms/step - loss: 0.7363 - accuracy: 0.6854 - val_loss: 7.5681 - val_accuracy: 0.2145
# Epoch 76/100
# 5307/5307 [==============================] - 8s 1ms/step - loss: 0.7365 - accuracy: 0.6853 - val_loss: 7.4590 - val_accuracy: 0.2154
# Epoch 77/100
# 5307/5307 [==============================] - 7s 1ms/step - loss: 0.7363 - accuracy: 0.6850 - val_loss: 7.5091 - val_accuracy: 0.2163
# Epoch 78/100
# 5307/5307 [==============================] - 7s 1ms/step - loss: 0.7362 - accuracy: 0.6854 - val_loss: 7.6126 - val_accuracy: 0.2143
# Epoch 79/100
# 5307/5307 [==============================] - 8s 1ms/step - loss: 0.7364 - accuracy: 0.6851 - val_loss: 7.6381 - val_accuracy: 0.2134
# Epoch 80/100
# 5307/5307 [==============================] - 7s 1ms/step - loss: 0.7363 - accuracy: 0.6853 - val_loss: 7.6397 - val_accuracy: 0.2208
# Epoch 81/100
# 5307/5307 [==============================] - 7s 1ms/step - loss: 0.7363 - accuracy: 0.6853 - val_loss: 7.6583 - val_accuracy: 0.2125
# Epoch 82/100
# 5307/5307 [==============================] - 5s 986us/step - loss: 0.7363 - accuracy: 0.6846 - val_loss: 7.6808 - val_accuracy: 0.2163
# Epoch 83/100
# 5307/5307 [==============================] - 7s 1ms/step - loss: 0.7362 - accuracy: 0.6852 - val_loss: 7.7448 - val_accuracy: 0.2077
# Epoch 84/100
# 5307/5307 [==============================] - 7s 1ms/step - loss: 0.7363 - accuracy: 0.6847 - val_loss: 7.5842 - val_accuracy: 0.2280
# Epoch 85/100
# 5307/5307 [==============================] - 8s 1ms/step - loss: 0.7362 - accuracy: 0.6854 - val_loss: 7.6348 - val_accuracy: 0.2155
# Epoch 86/100
# 5307/5307 [==============================] - 6s 1ms/step - loss: 0.7362 - accuracy: 0.6852 - val_loss: 7.5844 - val_accuracy: 0.2116
# Epoch 87/100
# 5307/5307 [==============================] - 8s 1ms/step - loss: 0.7361 - accuracy: 0.6854 - val_loss: 7.6903 - val_accuracy: 0.2198
# Epoch 88/100
# 5307/5307 [==============================] - 6s 1ms/step - loss: 0.7363 - accuracy: 0.6853 - val_loss: 7.6518 - val_accuracy: 0.2152
# Epoch 89/100
# 5307/5307 [==============================] - 7s 1ms/step - loss: 0.7362 - accuracy: 0.6852 - val_loss: 7.6925 - val_accuracy: 0.2153
# Epoch 90/100
# 5307/5307 [==============================] - 7s 1ms/step - loss: 0.7363 - accuracy: 0.6855 - val_loss: 7.5944 - val_accuracy: 0.2215
# Epoch 91/100
# 5307/5307 [==============================] - 7s 1ms/step - loss: 0.7361 - accuracy: 0.6852 - val_loss: 7.6731 - val_accuracy: 0.2153
# Epoch 92/100
# 5307/5307 [==============================] - 7s 1ms/step - loss: 0.7363 - accuracy: 0.6850 - val_loss: 7.6795 - val_accuracy: 0.2167
# Epoch 93/100
# 5307/5307 [==============================] - 8s 1ms/step - loss: 0.7363 - accuracy: 0.6853 - val_loss: 7.6267 - val_accuracy: 0.2183
# Epoch 94/100
# 5307/5307 [==============================] - 8s 1ms/step - loss: 0.7362 - accuracy: 0.6849 - val_loss: 7.6211 - val_accuracy: 0.2174
# Epoch 95/100
# 5307/5307 [==============================] - 7s 1ms/step - loss: 0.7362 - accuracy: 0.6859 - val_loss: 7.6518 - val_accuracy: 0.2167
# Epoch 96/100
# 5307/5307 [==============================] - 8s 1ms/step - loss: 0.7363 - accuracy: 0.6857 - val_loss: 7.6668 - val_accuracy: 0.2167
# Epoch 97/100
# 5307/5307 [==============================] - 8s 1ms/step - loss: 0.7361 - accuracy: 0.6850 - val_loss: 7.7325 - val_accuracy: 0.2097
# Epoch 98/100
# 5307/5307 [==============================] - 7s 1ms/step - loss: 0.7363 - accuracy: 0.6852 - val_loss: 7.7748 - val_accuracy: 0.2183
# Epoch 99/100
# 5307/5307 [==============================] - 7s 1ms/step - loss: 0.7363 - accuracy: 0.6854 - val_loss: 7.7124 - val_accuracy: 0.2204
# Epoch 100/100
# 5307/5307 [==============================] - 8s 1ms/step - loss: 0.7361 - accuracy: 0.6853 - val_loss: 7.6767 - val_accuracy: 0.2160
# 5307/5307 [==============================] - 4s 803us/step - loss: 0.7340 - accuracy: 0.6861
# Train score: [0.7340368032455444, 0.6861120462417603]
# 1769/1769 [==============================] - 1s 656us/step - loss: 7.6767 - accuracy: 0.2160
# Test score: [7.676692008972168, 0.2160094678401947]
